# %% [markdown]
# # PANDAS 1ST TO LAST

# %%
import pandas as pd
import numpy as np

dict1={'name':['Harry','Rohan','Bikash','Subh'],
       'Marks':[80,50,90,70],
       'city':['Rampur','Kolkata','Sankarpur','Bareilly']
}

df=pd.DataFrame(dict1)
df
# Out:
#      name  Marks       city
# 0   Harry     80     Rampur
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.to_csv('rakesh.csv',index=False)

# %%
read_csv=pd.read_csv('rakesh.csv')
read_csv
# Out:
#      name  Marks       city
# 0   Harry     80     Rampur
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.head(2)
# Out:
#     name  Marks     city
# 0  Harry     80   Rampur
# 1  Rohan     50  Kolkata

# %%
df.tail(2)
# Out:
#      name  Marks       city
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   72.500000
# std    17.078251
# min    50.000000
# 25%    65.000000
# 50%    75.000000
# 75%    82.500000
# max    90.000000

# %%
dict2={'Train.no':[234,345,675,345],
       'Speed':[50,60,70,80],
       'City':['charbatia','cutack','kapilash','puri']
}
dict2
# Out:
# {'Train.no': [234, 345, 675, 345],
#  'Speed': [50, 60, 70, 80],
#  'City': ['charbatia', 'cutack', 'kapilash', 'puri']}

# %%
df1=pd.DataFrame(dict2)
df1
# Out:
#    Train.no  Speed       City
# 0       234     50  charbatia
# 1       345     60     cutack
# 2       675     70   kapilash
# 3       345     80       puri

# %%
df1.to_csv('train.csv',index=False)

# %%
read=pd.read_csv('train.csv')
read
# Out:
#    Train.no  Speed       City
# 0       234     50  charbatia
# 1       345     60     cutack
# 2       675     70   kapilash
# 3       345     80       puri

# %%
read['Speed']
# Out:
# 0    50
# 1    60
# 2    70
# 3    80
# Name: Speed, dtype: int64

# %%
read['Speed'][0]
# Out:
# 50

# %%
read['Speed'][0]=55
# Out:
# C:\Users\NABAKU~1\AppData\Local\Temp/ipykernel_6680/1861407082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read['Speed'][0]=55

# %%
read
# Out:
#    Train.no  Speed       City
# 0       234     55  charbatia
# 1       345     60     cutack
# 2       675     70   kapilash
# 3       345     80       puri

# %%
read
# Out:
#    Train.no  Speed       City
# 0       234     55  charbatia
# 1       345     60     cutack
# 2       675     70   kapilash
# 3       345     80       puri

# %%
df1.index=['first','second','third','fourth']
df1
# Out:
#         Train.no  Speed       City
# first        234     50  charbatia
# second       345     60     cutack
# third        675     70   kapilash
# fourth       345     80       puri

# %%
df1['Speed']
# Out:
# first     50
# second    60
# third     70
# fourth    80
# Name: Speed, dtype: int64

# %%
type(df1['Speed'])
# Out:
# pandas.core.series.Series

# %%
f=df1['Speed']
type(f)
# Out:
# pandas.core.series.Series

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
ser=pd.Series(np.random.rand(4))
ser
# Out:
# 0    0.884568
# 1    0.659652
# 2    0.334685
# 3    0.124128
# dtype: float64

# %%
newdf=pd.DataFrame(np.random.rand(334,5))
newdf
# Out:
#             0         1         2         3         4
# 0    0.354215  0.987086  0.423679  0.468449  0.092752
# 1    0.278290  0.680282  0.936018  0.176613  0.798696
# 2    0.906058  0.517449  0.024392  0.246436  0.713023
# 3    0.115409  0.376901  0.751764  0.357301  0.902085
# 4    0.997417  0.010063  0.672012  0.054608  0.597329
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,'B']=7070
newdf
# Out:
#             A            B         C         D         E     0
# 0         657  7070.000000  0.423679  0.468449  0.092752  56.0
# 1     0.27829     0.680282  0.936018  0.176613  0.798696   NaN
# 2    0.906058     0.517449  0.024392  0.246436  0.713023   NaN
# 3    0.115409     0.376901  0.751764  0.357301  0.902085   NaN
# 4    0.997417     0.010063  0.672012  0.054608  0.597329   NaN
# ..        ...          ...       ...       ...       ...   ...
# 329  0.001786     0.856693  0.293684  0.471204  0.446241   NaN
# 330  0.759941     0.976883  0.368269  0.695091  0.495378   NaN
# 331  0.270172     0.696916  0.121414  0.948083  0.125345   NaN
# 332  0.665732     0.845495  0.357162  0.253982  0.880736   NaN
# 333  0.721733     0.244067  0.854968  0.862972  0.477702   NaN
#
# [334 rows x 6 columns]

# %%
newdf.loc[[0,2],['A','C']]
# Out:
#           A         C
# 0       657  0.423679
# 2  0.906058  0.024392

# %%
newdf.loc[:,['A','B']]
# Out:
#             A            B
# 0         657  7070.000000
# 1     0.27829     0.680282
# 2    0.906058     0.517449
# 3    0.115409     0.376901
# 4    0.997417     0.010063
# ..        ...          ...
# 329  0.001786     0.856693
# 330  0.759941     0.976883
# 331  0.270172     0.696916
# 332  0.665732     0.845495
# 333  0.721733     0.244067
#
# [334 rows x 2 columns]

# %%
newdf[:,['A','B']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NABAKU~1\AppData\Local\Temp/ipykernel_6680/834778486.py in <module>
# ----> 1 newdf[:,['A','B']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1   0.27829  0.680282  0.936018  0.176613  0.798696 NaN
# 2  0.906058  0.517449  0.024392  0.246436  0.713023 NaN

# %%
newdf.drop(0,axis=1,inplace=True)

# %%
newdf
# Out:
#             A            B         C         D         E
# 0         657  7070.000000  0.423679  0.468449  0.092752
# 1     0.27829     0.680282  0.936018  0.176613  0.798696
# 2    0.906058     0.517449  0.024392  0.246436  0.713023
# 3    0.115409     0.376901  0.751764  0.357301  0.902085
# 4    0.997417     0.010063  0.672012  0.054608  0.597329
# ..        ...          ...       ...       ...       ...
# 329  0.001786     0.856693  0.293684  0.471204  0.446241
# 330  0.759941     0.976883  0.368269  0.695091  0.495378
# 331  0.270172     0.696916  0.121414  0.948083  0.125345
# 332  0.665732     0.845495  0.357162  0.253982  0.880736
# 333  0.721733     0.244067  0.854968  0.862972  0.477702
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A            B         C         D         E
# 0       657  7070.000000  0.423679  0.468449  0.092752
# 1   0.27829     0.680282  0.936018  0.176613  0.798696
# 2  0.906058     0.517449  0.024392  0.246436  0.713023
# 3  0.115409     0.376901  0.751764  0.357301  0.902085
# 4  0.997417     0.010063  0.672012  0.054608  0.597329

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E
# 1     0.27829  0.680282  0.936018  0.176613  0.798696
# 3    0.115409  0.376901  0.751764  0.357301  0.902085
# 7     0.23151  0.849260  0.637070  0.144115  0.115899
# 10   0.032501  0.618747  0.969427  0.604999  0.758045
# 11   0.012324  0.640088  0.818589  0.200171  0.220753
# ..        ...       ...       ...       ...       ...
# 317  0.059488  0.804845  0.079990  0.612172  0.849081
# 319  0.055676  0.682621  0.914096  0.375461  0.617010
# 324  0.221852  0.344455  0.712895  0.448754  0.626668
# 329  0.001786  0.856693  0.293684  0.471204  0.446241
# 331  0.270172  0.696916  0.121414  0.948083  0.125345
#
# [115 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.9)]
# Out:
#             A         B         C         D         E
# 1     0.27829  0.680282  0.936018  0.176613  0.798696
# 10   0.032501  0.618747  0.969427  0.604999  0.758045
# 15   0.060288  0.779822  0.915943  0.367572  0.239190
# 16   0.250572  0.830509  0.964621  0.804474  0.769685
# 46   0.092747  0.998552  0.945872  0.989495  0.815374
# 131  0.049762  0.682045  0.919064  0.866620  0.969268
# 145  0.068007  0.040050  0.960057  0.650933  0.847769
# 237  0.159093  0.480099  0.932273  0.921486  0.011339
# 255  0.116696  0.324778  0.977913  0.646770  0.846085
# 319  0.055676  0.682621  0.914096  0.375461  0.617010

# %%
newdf.iloc[0]
# Out:
# A         657
# B      7070.0
# C    0.423679
# D    0.468449
# E    0.092752
# Name: 0, dtype: object

# %%
newdf.loc[0]
# Out:
# A         657
# B      7070.0
# C    0.423679
# D    0.468449
# E    0.092752
# Name: 0, dtype: object

# %%
newdf.iloc[0,2]
# Out:
# 0.42367857192105607

# %%
newdf.loc[0,'C']
# Out:
# 0.42367857192105607

# %%
newdf.iloc[[0,2],[1,2]]
# Out:
#              B         C
# 0  7070.000000  0.423679
# 2     0.517449  0.024392

# %%
new=pd.DataFrame(np.random.rand(4,2))
new
# Out:
#           0         1
# 0  0.383555  0.868622
# 1  0.509096  0.527214
# 2  0.855875  0.256639
# 3  0.677102  0.890773

# %%
new=new.loc[new[0]>0.65]
new
# Out:
#           0         1
# 2  0.855875  0.256639
# 3  0.677102  0.890773

# %%
new.sort_values([0],inplace=True)
# Out:
# C:\Users\NABA KUMAR ROUT\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
new
# Out:
#           0         1
# 3  0.677102  0.890773
# 2  0.855875  0.256639

# %%
new.reset_index()
# Out:
#    index         0         1
# 0      3  0.677102  0.890773
# 1      2  0.855875  0.256639

# %%
new.reset_index(drop=True,inplace=True)

# %%
new
# Out:
#           0         1
# 0  0.677102  0.890773
# 1  0.855875  0.256639

# %%
new[0]=None
new
# Out:
# C:\Users\NABAKU~1\AppData\Local\Temp/ipykernel_6680/265300297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[0]=None
#       0         1
# 0  None  0.890773
# 1  None  0.256639

# %%
new.loc[:,[0]]=None
new
# Out:
# C:\Users\NABA KUMAR ROUT\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#       0         1
# 0  None  0.890773
# 1  None  0.256639

# %%
new[0].isnull()
# Out:
# 0    True
# 1    True
# Name: 0, dtype: bool

# %%
new.isnull()
# Out:
#       0      1
# 0  True  False
# 1  True  False

# %%
new.dropna()
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
new.dropna(how='all')
# Out:
#       0         1
# 0  None  0.890773
# 1  None  0.256639

# %%
new.dropna(how='all',axis=1)
# Out:
#           1
# 0  0.890773
# 1  0.256639

# %%
df
# Out:
#      name  Marks       city
# 0   Harry     80     Rampur
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.loc[0,'name']='Bikash'

# %%
df
# Out:
#      name  Marks       city
# 0  Bikash     80     Rampur
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.drop_duplicates(subset=['name'])
# Out:
#      name  Marks      city
# 0  Bikash     80    Rampur
# 1   Rohan     50   Kolkata
# 3    Subh     70  Bareilly

# %%
df.drop_duplicates(subset=['name'],keep='first')
# Out:
#      name  Marks      city
# 0  Bikash     80    Rampur
# 1   Rohan     50   Kolkata
# 3    Subh     70  Bareilly

# %%
df.drop_duplicates(subset=['name'],keep='last')
# Out:
#      name  Marks       city
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.drop_duplicates(subset=['name'],keep=False)
# Out:
#     name  Marks      city
# 1  Rohan     50   Kolkata
# 3   Subh     70  Bareilly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   Marks   4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 128.0+ bytes

# %%
df.loc[:,[1]]=None

# %%
df
# Out:
#      name  Marks       city     1
# 0  Bikash     80     Rampur  None
# 1   Rohan     50    Kolkata  None
# 2  Bikash     90  Sankarpur  None
# 3    Subh     70   Bareilly  None

# %%
df.drop([1],axis=1)
# Out:
#      name  Marks       city
# 0  Bikash     80     Rampur
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.loc[:,['Marks']]=None

# %%
df
# Out:
#      name Marks       city     1
# 0  Bikash  None     Rampur  None
# 1   Rohan  None    Kolkata  None
# 2  Bikash  None  Sankarpur  None
# 3    Subh  None   Bareilly  None

# %%
df.loc[2,'Marks']=90

# %%
df
# Out:
#      name Marks       city     1
# 0  Bikash  None     Rampur  None
# 1   Rohan  None    Kolkata  None
# 2  Bikash    90  Sankarpur  None
# 3    Subh  None   Bareilly  None

# %%
df['Marks'].value_counts()
# Out:
# 90    1
# Name: Marks, dtype: int64

# %%
df['Marks'].value_counts(dropna=False)
# Out:
# NaN     3
# 90.0    1
# Name: Marks, dtype: int64

# %%
df.notnull()
# Out:
#    name  Marks  city      1
# 0  True  False  True  False
# 1  True  False  True  False
# 2  True   True  True  False
# 3  True  False  True  False

# %%
df.drop([1],axis=1,inplace=True)

# %%
df
# Out:
#      name Marks       city
# 0  Bikash  None     Rampur
# 1   Rohan  None    Kolkata
# 2  Bikash    90  Sankarpur
# 3    Subh  None   Bareilly

# %%
df.notnull()
# Out:
#    name  Marks  city
# 0  True  False  True
# 1  True  False  True
# 2  True   True  True
# 3  True  False  True

# %%
df.isnull()
# Out:
#     name  Marks   city
# 0  False   True  False
# 1  False   True  False
# 2  False  False  False
# 3  False   True  False

# %%
excel=pd.read_csv('newexcel.csv')

# %%
excel
# Out:
#    Train.nos1  Speeds1     Citys1
# 0         234       50  charbatia
# 1         345       60     cutack
# 2         675       70   kapilash
# 3         345       80       puri

# %%
excel=pd.read_csv('newexcel.csv')

# %%
excel
# Out:
#    Train.nos1  Speeds1     Citys1
# 0         234       50  charbatia
# 1         345       60     cutack
# 2         675       70   kapilash
# 3         345       80       puri

# %%
excel=pd.read_excel('book1.xlsx')

# %%
excel
# Out:
#    no.s1   names1     citys1
# 0      0   bikash  charbatia
# 1      1   rakesh     cutack
# 2      2  sushama   kapilash
# 3      3  pramila       puri

# %%
excel=pd.read_excel('book1.xlsx',sheet_name='Sheet2')

# %%
excel
# Out:
#    no.s2   names2     citys2
# 0      0   bikash  charbatia
# 1      1   rakesh     cutack
# 2      2  sushama   kapilash
# 3      3  pramila       puri

# %%
excel.iloc[0,1]='Bikash'

# %%
excel
# Out:
#    no.s2   names2     citys2
# 0      0   Bikash  charbatia
# 1      1   rakesh     cutack
# 2      2  sushama   kapilash
# 3      3  pramila       puri

# %%
excel.to_excel('book1.xlsx',sheet_name='Sheet2',index=False)

# %%
excel
# Out:
#    no.s2   names2     citys2
# 0      0   Bikash  charbatia
# 1      1   rakesh     cutack
# 2      2  sushama   kapilash
# 3      3  pramila       puri

# %%
data=pd.read_excel('newexcel.xlsx')

# %%
data
# Out:
#    Train.nos1  Speeds1     Citys1
# 0         234       50  charbatia
# 1         345       60     cutack
# 2         675       70   kapilash
# 3         345       80       puri

# %%
data=pd.read_excel('newexcel.xlsx',sheet_name='Sheet2')

# %%
data
# Out:
#    Train.nos2  Speeds2     Citys2
# 0         234       50  charbatia
# 1         345       60     cutack
# 2         675       70   kapilash
# 3         345       80       puri

# %%
dict2=dict1.copy()

# %%
dict2
# Out:
# {'name': ['Harry', 'Rohan', 'Bikash', 'Subh'],
#  'Marks': [80, 50, 90, 70],
#  'city': ['Rampur', 'Kolkata', 'Sankarpur', 'Bareilly']}

# %%
df=pd.DataFrame(dict2)
df
# Out:
#      name  Marks       city
# 0   Harry     80     Rampur
# 1   Rohan     50    Kolkata
# 2  Bikash     90  Sankarpur
# 3    Subh     70   Bareilly

# %%
df.iloc[0,0]='rakesh'

# %%
df.iloc[0,2]='sankar-pur'

# %%
df
# Out:
#      name  Marks        city
# 0  rakesh     80  sankar-pur
# 1   Rohan     50     Kolkata
# 2  Bikash     90   Sankarpur
# 3    Subh     70    Bareilly

# %%
df.to_csv('data2.csv',index=False)

# %%
data2=pd.read_csv('data2.csv')

# %%
data2
# Out:
#      name  Marks        city
# 0  rakesh     80  sankar-pur
# 1   Rohan     50     Kolkata
# 2  Bikash     90   Sankarpur
# 3    Subh     70    Bareilly

# %%
data2.iloc[1,0]='kalia'

# %%
data2
# Out:
#      name  Marks        city (1, 0)
# 0  rakesh     80  sankar-pur  kalia
# 1   kalia     50     Kolkata  kalia
# 2  Bikash     90   Sankarpur  kalia
# 3    Subh     70    Bareilly  kalia

# %%
data2.drop([(1,0)],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\NABAKU~1\AppData\Local\Temp/ipykernel_6680/2158537858.py in <module>
# ----> 1 data2.drop([(1,0)],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data2
# Out:
#      name  Marks        city
# 0  rakesh     80  sankar-pur
# 1   kalia     50     Kolkata
# 2  Bikash     90   Sankarpur
# 3    Subh     70    Bareilly

# %%
data2.iloc[1,2]='sankar-pur'
data2.iloc[3,0]='babul'
data2.iloc[3,2]='sankar-pur'

# %%
data2
# Out:
#      name  Marks        city
# 0  rakesh     80  sankar-pur
# 1   kalia     50  sankar-pur
# 2  Bikash     90   Sankarpur
# 3   babul     70  sankar-pur

# %%
data2.to_csv('data2.csv',index=False)
